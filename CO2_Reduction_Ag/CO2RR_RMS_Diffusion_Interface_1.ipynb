# %%
using Pkg
Pkg.activate(ENV["PYTHON_JULIAPKG_PROJECT"])
using ReactionMechanismSimulator
# Out:
#   Activating project at `~/miniforge3/envs/rmg_env3/julia_env`
# Precompiling packages...
#    2215.3 ms  ? DomainSets
#    2120.3 ms  ? Symbolics
#    4640.9 ms  ? ModelingToolkit
#   22651.8 ms  ? SciMLSensitivity
# Info Given ReactionMechanismSimulator was explicitly requested, output will be shown live
# WARNING: Method definition getGibbs(P, N) where {N<:Number, P<:ReactionMechanismSimulator.AbstractThermo} in module ReactionMechanismSimulator at /home/danieltori/ReactionMechanismSimulator.jl/src/Calculators/Thermo.jl:6 overwritten on the same line (check for duplicate calls to `include`).
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    2537.0 ms  ? ReactionMechanismSimulator
# [ Info: Precompiling ReactionMechanismSimulator [c2d78dd2-25c4-5b79-bebc-be6c69dd440f]
# WARNING: Method definition getGibbs(P, N) where {N<:Number, P<:ReactionMechanismSimulator.AbstractThermo} in module ReactionMechanismSimulator at /home/danieltori/ReactionMechanismSimulator.jl/src/Calculators/Thermo.jl:6 overwritten on the same line (check for duplicate calls to `include`).
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing ReactionMechanismSimulator [c2d78dd2-25c4-5b79-bebc-be6c69dd440f].
# ┌ Warning: Replacing docs for `ReactionMechanismSimulator.getpairs :: Tuple{T} where T<:ReactionMechanismSimulator.AbstractReaction` in module `ReactionMechanismSimulator`
# └ @ Base.Docs docs/Docs.jl:243
# ┌ Warning: Replacing docs for `ReactionMechanismSimulator.getsimilarity :: Union{Tuple{T2}, Tuple{T}, Tuple{T, T2}} where {T<:ReactionMechanismSimulator.AbstractSpecies, T2<:ReactionMechanismSimulator.AbstractSpecies}` in module `ReactionMechanismSimulator`
# └ @ Base.Docs docs/Docs.jl:243
# WARNING: method definition for getreactionindices at /home/danieltori/ReactionMechanismSimulator.jl/src/Phase.jl:316 declares type variable Q but does not use it.
# WARNING: method definition for Inlet at /home/danieltori/ReactionMechanismSimulator.jl/src/Interface.jl:255 declares type variable B but does not use it.
# WARNING: method definition for #ConstantTPDomain#338 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:43 declares type variable W but does not use it.
# WARNING: method definition for #ConstantTPDomain#338 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:43 declares type variable Q but does not use it.
# WARNING: method definition for #ConstantTPDomain#338 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:43 declares type variable E but does not use it.
# WARNING: method definition for #ConstantVDomain#349 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:121 declares type variable Q but does not use it.
# WARNING: method definition for #ConstantPDomain#358 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:189 declares type variable Q but does not use it.
# WARNING: method definition for #ParametrizedTPDomain#367 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:258 declares type variable Q but does not use it.
# WARNING: method definition for #ParametrizedVDomain#376 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:338 declares type variable Q but does not use it.
# WARNING: method definition for #ParametrizedVDomain#376 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:338 declares type variable E but does not use it.
# WARNING: method definition for #ParametrizedPDomain#385 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:415 declares type variable Q but does not use it.
# WARNING: method definition for #ParametrizedPDomain#385 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:415 declares type variable E but does not use it.
# WARNING: method definition for #ConstantTVDomain#394 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:502 declares type variable W but does not use it.
# WARNING: method definition for #ConstantTVDomain#394 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:502 declares type variable Q but does not use it.
# WARNING: method definition for #ParametrizedTConstantVDomain#405 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:587 declares type variable Q but does not use it.
# WARNING: method definition for #ConstantTAPhiDomain#414 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:671 declares type variable W but does not use it.
# WARNING: method definition for #ConstantTAPhiDomain#414 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:671 declares type variable E but does not use it.
# WARNING: method definition for #FragmentBasedConstantTrhoDomain#423 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:763 declares type variable X3 but does not use it.
# WARNING: method definition for #FragmentBasedConstantTrhoDomain#423 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:763 declares type variable E1 but does not use it.
# WARNING: method definition for #FragmentBasedConstantTrhoDomain#423 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:763 declares type variable X1 but does not use it.
# WARNING: method definition for #ConstantTLiqFilmDomain#432 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:871 declares type variable W but does not use it.
# WARNING: method definition for #ConstantTLiqFilmDomain#432 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:871 declares type variable Q but does not use it.
# WARNING: method definition for calcthermo at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1591 declares type variable J but does not use it.
# WARNING: method definition for calcthermo at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1663 declares type variable J but does not use it.
# WARNING: method definition for calcthermo at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1750 declares type variable J but does not use it.
# WARNING: method definition for calcthermo at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1829 declares type variable J but does not use it.
# WARNING: method definition for #calcdomainderivatives!#487 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1866 declares type variable Y but does not use it.
# WARNING: method definition for #calcdomainderivatives!#487 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1866 declares type variable W but does not use it.
# WARNING: method definition for #calcdomainderivatives!#488 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1892 declares type variable Y but does not use it.
# WARNING: method definition for #calcdomainderivatives!#488 at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:1892 declares type variable W but does not use it.
# WARNING: method definition for jacobianpnsderiv! at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:3130 declares type variable Q3 but does not use it.
# WARNING: method definition for jacobianpnsderiv! at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:3239 declares type variable Q3 but does not use it.
# WARNING: method definition for jacobianpnsderiv! at /home/danieltori/ReactionMechanismSimulator.jl/src/Domain.jl:3325 declares type variable Q3 but does not use it.
# Precompiling packages...
#    1360.8 ms  ? DomainSets
# Info Given Symbolics was explicitly requested, output will be shown live
# WARNING: Method definition isapprox(IntervalSets.AbstractInterval{T} where T, IntervalSets.AbstractInterval{T} where T) in module IntervalSets at /home/danieltori/.julia/packages/IntervalSets/K4CRG/src/IntervalSets.jl:297 overwritten in module DomainSets at /home/danieltori/.julia/packages/DomainSets/aafhp/src/domains/interval.jl:52.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    2154.5 ms  ? Symbolics
# [ Info: Precompiling Symbolics [0c5d862f-8b57-4792-8d23-62f2024744c7]
# WARNING: Method definition isapprox(IntervalSets.AbstractInterval{T} where T, IntervalSets.AbstractInterval{T} where T) in module IntervalSets at /home/danieltori/.julia/packages/IntervalSets/K4CRG/src/IntervalSets.jl:297 overwritten in module DomainSets at /home/danieltori/.julia/packages/DomainSets/aafhp/src/domains/interval.jl:52.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing Symbolics [0c5d862f-8b57-4792-8d23-62f2024744c7].
# Precompiling packages...
# Info Given DomainSets was explicitly requested, output will be shown live
# WARNING: Method definition isapprox(IntervalSets.AbstractInterval{T} where T, IntervalSets.AbstractInterval{T} where T) in module IntervalSets at /home/danieltori/.julia/packages/IntervalSets/K4CRG/src/IntervalSets.jl:297 overwritten in module DomainSets at /home/danieltori/.julia/packages/DomainSets/aafhp/src/domains/interval.jl:52.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    1341.6 ms  ? DomainSets
# [ Info: Precompiling DomainSets [5b8099bc-c8ec-5219-889f-1d9e522a28bf]
# WARNING: Method definition isapprox(IntervalSets.AbstractInterval{T} where T, IntervalSets.AbstractInterval{T} where T) in module IntervalSets at /home/danieltori/.julia/packages/IntervalSets/K4CRG/src/IntervalSets.jl:297 overwritten in module DomainSets at /home/danieltori/.julia/packages/DomainSets/aafhp/src/domains/interval.jl:52.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing DomainSets [5b8099bc-c8ec-5219-889f-1d9e522a28bf].
# Precompiling packages...
#    1357.6 ms  ? DomainSets
#    1845.5 ms  ? Symbolics
# Info Given ModelingToolkit was explicitly requested, output will be shown live
# WARNING: Method definition isapprox(IntervalSets.AbstractInterval{T} where T, IntervalSets.AbstractInterval{T} where T) in module IntervalSets at /home/danieltori/.julia/packages/IntervalSets/K4CRG/src/IntervalSets.jl:297 overwritten in module DomainSets at /home/danieltori/.julia/packages/DomainSets/aafhp/src/domains/interval.jl:52.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#    4933.6 ms  ? ModelingToolkit
# [ Info: Precompiling ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78]
# ┌ Warning: Module Symbolics with build ID ffffffff-ffff-ffff-39fb-d98576abfc85 is missing from the cache.
# │ This may mean Symbolics [0c5d862f-8b57-4792-8d23-62f2024744c7] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2018
# [ Info: Skipping precompilation since __precompile__(false). Importing ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78].
# WARNING: method definition for #Reactor#622 at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:267 declares type variable F but does not use it.
# WARNING: method definition for addreactionratecontributions! at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:465 declares type variable T but does not use it.
# WARNING: method definition for addreactionratecontributions! at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:509 declares type variable W2 but does not use it.
# WARNING: method definition for addreactionratecontributions! at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:509 declares type variable T but does not use it.
# WARNING: method definition for addreactionratecontributions! at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:556 declares type variable T but does not use it.
# WARNING: method definition for addreactionratecontributionsforwardreverse! at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:601 declares type variable T but does not use it.
# WARNING: method definition for jacobianyforwarddiff at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:789 declares type variable Q but does not use it.
# WARNING: method definition for jacobianpforwarddiff at /home/danieltori/ReactionMechanismSimulator.jl/src/Reactor.jl:841 declares type variable Q but does not use it.
# Precompiling packages...
# Info Given SciMLSensitivity was explicitly requested, output will be shown live
# WARNING: Method definition (::ChainRulesCore.ProjectTo{var"#s1108"<:(ChainRulesCore.Tangent{var"#s1107", T} where T where var"#s1107"<:Tuple), D<:(NamedTuple{names, T} where T<:Tuple where names)})(StaticArraysCore.SArray{S, T, N, L} where L where N where T where S<:Tuple) in module StaticArraysChainRulesCoreExt at /home/danieltori/.julia/packages/StaticArrays/DsPgf/ext/StaticArraysChainRulesCoreExt.jl:10 overwritten in module SciMLSensitivity at /home/danieltori/.julia/packages/SciMLSensitivity/VumeD/src/staticarrays.jl:2.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#   21022.2 ms  ? SciMLSensitivity
# [ Info: Precompiling SciMLSensitivity [1ed8b502-d754-442c-8d5d-10ac956f44a1]
# WARNING: Method definition (::ChainRulesCore.ProjectTo{var"#s1108"<:(ChainRulesCore.Tangent{var"#s1107", T} where T where var"#s1107"<:Tuple), D<:(NamedTuple{names, T} where T<:Tuple where names)})(StaticArraysCore.SArray{S, T, N, L} where L where N where T where S<:Tuple) in module StaticArraysChainRulesCoreExt at /home/danieltori/.julia/packages/StaticArrays/DsPgf/ext/StaticArraysChainRulesCoreExt.jl:10 overwritten in module SciMLSensitivity at /home/danieltori/.julia/packages/SciMLSensitivity/VumeD/src/staticarrays.jl:2.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing SciMLSensitivity [1ed8b502-d754-442c-8d5d-10ac956f44a1].
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:554 declares type variable V but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:554 declares type variable Q but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:560 declares type variable V but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:560 declares type variable Q but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:566 declares type variable V but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:566 declares type variable Q but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:572 declares type variable V but does not use it.
# WARNING: method definition for sensg at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:572 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:579 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:579 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:583 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:583 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:587 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:587 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:591 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:591 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:646 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:646 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:650 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:650 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:654 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:654 declares type variable Q but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:658 declares type variable V but does not use it.
# WARNING: method definition for g at /home/danieltori/ReactionMechanismSimulator.jl/src/Simulation.jl:658 declares type variable Q but does not use it.
# ┌ Warning: Replacing docs for `ReactionMechanismSimulator.plotrops :: Union{Tuple{X}, Tuple{Y}, Tuple{Y, X}} where {Y<:ReactionMechanismSimulator.Simulation, X<:AbstractString}` in module `ReactionMechanismSimulator`
# └ @ Base.Docs docs/Docs.jl:243
# ┌ Warning: Replacing docs for `ReactionMechanismSimulator.plotrops :: Union{Tuple{X}, Tuple{Y}, Tuple{Y, X}} where {Y<:ReactionMechanismSimulator.Simulation, X<:AbstractString}` in module `ReactionMechanismSimulator`
# └ @ Base.Docs docs/Docs.jl:243
# WARNING: method definition for #plotradicalrops#952 at /home/danieltori/ReactionMechanismSimulator.jl/src/Plotting.jl:371 declares type variable X but does not use it.

# %%
using PythonPlot
using DifferentialEquations
using Sundials
using SciMLBase
using QuadGK

# %%
outdict = readinput("/home/danieltori/CO2_RR_RMG/CO2_Reduction_Ag/Ag_C2_042925.rms")
# Out:
# [20:58:11] WARNING: not removing hydrogen atom without neighbors
# [20:58:11] WARNING: not removing hydrogen atom without neighbors
# ┌ Warning: failed to generate StokesDiffusivity model for species vacantX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CO2X
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CHO2X
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CO2HX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OCX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CH2O2X
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CHOX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CH2OX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species HOX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])C(=O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species HX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species H2OX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=CC(=O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=O.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=C=O.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC#[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])C#[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CH2X
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])C[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]CO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])OC[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species C=C=O.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C(C[Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])C=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]OC=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=C=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CHX
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])CO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]OCO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=C[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]COO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=CO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])C(O)=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC(=[Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC([Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])C(O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=CO.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=C([Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species COC(=O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC(=O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC(=O)O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CH3X
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])CO
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OCO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C([Pt])OC=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species COO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [H][H].[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C(C=[Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CO.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C(C#[Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C=C(O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC(O)[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species OC(O)=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC(=O)O.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C(O)C[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C(O)C=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=C(O)C#[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC(O)=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]=C=C=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC(O)([Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC(=[Pt])O[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species CC#[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]C#CO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]OC#CO[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species COC=O.[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=COC[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=COC=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species O=COC#[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]C=C=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# ┌ Warning: failed to generate StokesDiffusivity model for species [Pt]=CC=[Pt]
# └ @ ReactionMechanismSimulator ~/ReactionMechanismSimulator.jl/src/Parse.jl:352
# Dict{Any, Any} with 4 entries:
#   "Solvents"              => Solvent[Solvent("water", RiedelViscosity{Float64}(…
#   Set(["gas", "surface"]) => Dict{Any, Any}("Reactions"=>ElementaryReaction[pro…
#   "gas"                   => Dict{Any, Any}("Species"=>Species[Species{NASA{Emp…
#   "surface"               => Dict{Any, Any}("Species"=>Species[Species{NASA{Emp…

# %%
boundarylayerspcs = outdict["gas"]["Species"]
boundarylayerrxns = outdict["gas"]["Reactions"]
surfspcs = outdict["surface"]["Species"]
surfrxns = outdict["surface"]["Reactions"]
interfacerxns = outdict[Set(["surface", "gas"])]["Reactions"]
solv = outdict["Solvents"][1];

# %%
sitedensity = 2.292e-5; # Ag111 site density is 2.294e-9 mol/cm^2 or 2.294e-5 mol/m^2
boundarylayer = IdealDiluteSolution(boundarylayerspcs,boundarylayerrxns,solv,name="boundarylayeruid",diffusionlimited=true);
surf = IdealSurface(surfspcs,surfrxns,sitedensity,name="surface");

# %%
# Reservoir is a 100 mL (100e-6 m^3) cell
# Proton concentration is 10^-7 mol/L (10^-4 mol/m^3)
# CO2 concentration is 0.01 mol/L (10 mol/m^3), saturation solubility ~0.03 mol/L
# AVratio in experiments is 36 m^-1 but is measured by surface area/reservoir volume
# Area of the electrode is therefore 3.6e1 m^-1 * 1e2 * 1e-6 m^3 = 3.6e-3 m^2 = 36 cm^2
# Assume boundary layer thickness d_bl = 1 mm or 1e-3 m
# Volume of the boundary layer V_bl = 3.6e-3 m^2 * 1e-3 m = 3.6e-6 m^3
# Actual AVratio is therefore 3.6e-3 m^2 / 3.6e-6 m^3 = 1e3 m^-1 (reciprocal of d_bl)
# Amount of sites is 2.943e-5 mol/m^2 * 3.6e-3 m^2 = 10.595e-8 mol

# For earlier simulations, a 100x linear scale factor is applied,
# so volume becomes 100e-6 m^3 * (1e2)^3 = 100 m^3,
# electrode area becomes 3.6e-3 * (1e2) ^2 = 3.6e1 m^2,
# AVratio becomes 3.6e1 m^2 / 1e2 m^3 = 0.36 m^-1
# Volume of the boundary layer becomes 3.6e1 m^2 * 1e-3 m = 3.6e-2 m^3

C_proton = 1e-7*1e3;
C_co2 = 1e-2*1e3;
C_default = 1e-12;
V_res = 1e3;
layer_thickness = 1e-6;
AVratio = 36;
A_surf = V_res*AVratio;
V_bl = A_surf*layer_thickness;
# V_bl = V_res;
sites = sitedensity*A_surf;

# The initial conditions for individual species are moles not concentration, so we need to multiply concentration by boundary layer volume
initialcondsboundarylayer = Dict(["proton"=>C_proton*V_bl,
                                  "CO2"=>C_co2*V_bl,
                                #   "H2"=>C_default*10*V_bl,
                                #   "O=CO"=>C_default*V_bl,
                                  "V"=>V_bl,"T"=>300,"Phi"=>0.0,"d"=>0.0]);
initialcondsreservoir = Dict(["proton"=>C_proton,
                              "CO2"=>C_co2,
                              "V"=>V_res,"T"=>300]);


# Assume voltage is -1.0 V vs. R.H.E. which equates to -1.414 V vs. S.H.E. at pH=7
initialcondssurf = Dict(["CO2X"=>0.1*sites,
        # "CHO2X"=>0.1*sites,
        # "CO2HX"=>0.1*sites,
        # "OX"=>0.1*sites,
        # "OCX"=>0.1*sites,
        "vacantX"=>0.9*sites,
        # "CH2O2X"=>0.05*sites,
        # "CHOX"=>0.04*sites,
        # "CH2OX"=>0.01*sites,
        "A"=>A_surf,"T"=>300,"Phi"=>-1.414]);

# %%
domainboundarylayer, y0boundarylayer, pboundarylayer = ConstantTVDomain(phase=boundarylayer, initialconds=initialcondsboundarylayer);
domaincat,y0cat,pcat = ConstantTAPhiDomain(phase=surf,
    initialconds=initialcondssurf);

# %%
# Set proton diffusivity to a higher value than calculated from Stokes Einstein equation
# The values are taken from DOI: 10.1039/C8SC01253A
# Values calculated from MD is 1.015 A^2/ps, experimental values are 0.932 A^2/ps.
# 1 A^2/ps = 1e-8 m^2/s
domainboundarylayer.diffusivity[6] = 0.932e-8
# Out:
# 9.32e-9

# %%
inter,pinter = ReactiveInternalInterfaceConstantTPhi(domainboundarylayer,
  domaincat,interfacerxns,298.15,A_surf);

# %%
# start with 1mm layer thickness
diffusionlayer = ConstantReservoirDiffusion(domainboundarylayer, initialcondsreservoir, A_surf, layer_thickness);

# %%
interfaces = [inter, diffusionlayer];

# %%
@time react,y0,p = Reactor((domainboundarylayer,domaincat), (y0boundarylayer,y0cat), (0.0, 1e3), interfaces, (pboundarylayer,pcat,pinter));
# Out:
#   6.647455 seconds (18.11 M allocations: 1.165 GiB, 8.20% gc time, 99.84% compilation time: <1% of which was recompilation)

# %%
@time sol = solve(react.ode,Sundials.CVODE_BDF(),abstol=1e-22,reltol=1e-8);
println(sol.t[end]);
println(sol.retcode);
# Out:
#   3.570993 seconds (5.32 M allocations: 696.517 MiB, 16.25% gc time, 90.89% compilation time)
# 1000.0
# Success

# %%
ssys = SystemSimulation(sol,(domainboundarylayer,domaincat,), interfaces,p);

# %%
"""
diffusive flux to the reservoir
"""
function flux_to_reservoir(sim,t,reservoirinterface)
    cs = concentrations(sim,t)
    return reservoirinterface.A .* sim.domain.diffusivity .* (cs - reservoirinterface.c) / reservoirinterface.layer_thickness
end

"""
Integrates the flux to the reservoir and computes the concentration assuming
there is no prior concentration of that species in the reservoir
"""
function get_reservoir_concentration(sim,t,reservoirinterface,Vres,C0)
    intg,err = quadgk(x -> flux_to_reservoir(sim,x,reservoirinterface), 0, t);
    intg[5] = 0;
    intg[6] = 0;
    return C0 + intg./Vres
end
# Out:
# get_reservoir_concentration

# %%
# Logarithmic time scale
t_vals = 10 .^ range(-12, stop=3, length=160);

# Compute reservoir concentrations
flux_vals = [flux_to_reservoir(ssys.sims[1], t, diffusionlayer) for t in t_vals]

conc_vals_bl = [concentrations(ssys.sims[1], t) for t in t_vals]
flux_matrix = hcat(flux_vals...);
conc_matrix_bl = hcat(conc_vals_bl...);

# %%
conc_0 = concentrations(ssys.sims[1], 0)
t_vals_2 = 10 .^ range(-9, stop=3, length=130);
conc_vals = [get_reservoir_concentration(ssys.sims[1], t, diffusionlayer, V_res, conc_0) for t in t_vals_2]
conc_matrix = hcat(conc_vals...);

# %%
function plotC_Reservoir(sim, cs, tvals, tol, exclude)
    clf()
    xs = cs
    maxes = maximum(xs, dims=2)

    time_filtered = tvals
    xs_filtered = xs

    # Custom species order and their corresponding names and color
    species_order = ["CO2", "proton", "H2", "O=CO", "C=O", "CO-2", "CCO", "CH4", "OCO", "COC", "COCO", "CC(=O)O", "COC=O"]
    color_map = Dict("CO2" => "black", "proton" => "grey", "H2" => "green",
                        "O=CO" => "red", "C=O" => "brown", "CO-2" => "blue", "CCO" => "magenta",
                        "CH4" => "brown", "OCO" => "orange", "COC" => "teal", "COCO" => "lime", "CC(=O)O" => "teal", "COC=O" => "lime")
    # Replacement map for species labels
    replacement_map = Dict("CO-2" => "CH3OH", "O=CO" => "HCOOH", "C=O" => "HCHO",
                            "CCO" => "C2H5OH", "OCO" => "CH2(OH)2", "COC" => "CH3OCH3", "COCO" => "CH3OCH2OH", "CC(=O)O" => "CH3COOH", "COC=O" => "CH3OCHO")

    # Build a map of species names to indices
    name_to_index = Dict(sim.domain.phase.species[i].name => i for i in 1:length(sim.domain.phase.species))
    # Keep track of whether the species is plotted, used for later checks
    plotted = falses(length(sim.domain.phase.species))

    # Plot species from the custom species dictionary
    for species_name in species_order
        if species_name in exclude
            continue
        end

        if haskey(name_to_index, species_name)
            i = name_to_index[species_name]

            if (maxes[i] > tol) || (species_name == "proton") || (species_name == "CCO")  # Always plot proton and ethanol
                plot_label = get(replacement_map, species_name, species_name)
                plot_color = color_map[species_name]

                plot(time_filtered, xs_filtered[i, :]/1000, label=plot_label, color=plot_color)
                plotted[i] = true  # Mark as plotted
            end
        end
    end

    # Plot any remaining species that passed tolerance but were not in species_order
    for i in 1:length(sim.domain.phase.species)
        if plotted[i] || sim.domain.phase.species[i].name in exclude
            continue
        end

        if maxes[i] > tol
            species_name = sim.domain.phase.species[i].name
            plot(time_filtered, xs_filtered[i, :]/1000, label=species_name)  # Default color
        end
    end

    xlabel("Time (s)", fontsize=14)
    ylabel("Bulk Concentration (mol/L)", fontsize=14)
    xticks(fontsize=14)
    yticks(fontsize=14)
    legend(loc="upper left", bbox_to_anchor=(0, 0.9), fontsize=12, ncol=2)
end
# Out:
# plotC_Reservoir (generic function with 1 method)

# %%
exclude_species = ["H2O", "O=CC=O", "O=CCO", "CC=O"]
plotC_Reservoir(ssys.sims[1], conc_matrix, t_vals_2, 1e-12, exclude_species)

xscale("log")
yscale("log")
xlim(1e-9, 1e3)
ylim(1e-20, 1e-1)
legend(loc="upper left", bbox_to_anchor=(0, 0.9), fontsize=12,  ncol=2)
title("Ag111@-1.0V vs. R.H.E., d = 10e-6 m")
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
clf()

for i in 1:size(flux_matrix, 1)
    if maximum(abs.(flux_matrix[i, :])) > 1e-10
        plot(t_vals, abs.(flux_matrix[i, :]), label=ssys.sims[1].domain.phase.species[i].name)

    end
end

xscale("log")
yscale("log")
xlabel("Time (s)")
ylabel("Diffusive Flux (mol/s)")
xlim(1e-12, 1e3)
ylim(1e-9, 1e1)
legend()
tight_layout()
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
clf()

# Define consistent color map for all species
color_map = Dict(
    "CO2" => "black", 
    "proton" => "grey", 
    "H2" => "green",
    "O=CO" => "red", 
    "C=O" => "brown", 
    "CO-2" => "blue", 
    "CCO" => "magenta",
    "CH4" => "olive", 
    "OCO" => "orange", 
    "COC" => "teal", 
    "COCO" => "lime", 
    "CC(=O)O" => "purple", 
    "COC=O" => "cyan",
    "H2O" => "lightblue",
    "O=CC=O" => "pink",
    "O=CCO" => "darkred",
    "CC=O" => "gold"
)

for i in 1:size(conc_matrix_bl, 1)
    if maximum(conc_matrix_bl[i, :]) > 1e-10
        species_name = ssys.sims[1].domain.phase.species[i].name
        # Get color from map, or use default if not found
        plot_color = get(color_map, species_name, nothing)
        plot(t_vals, conc_matrix_bl[i, :]/1e3, label=species_name, color=plot_color)
    end   
end

xscale("log")
yscale("log")
xlabel("Time (s)", fontsize=12)
ylabel("Boundary Layer Concentrations (mol/L)", fontsize=12)
xlim(1e-12, 1e3)
ylim(1e-18, 1)
legend(fontsize=10)
tight_layout()
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
# Helper function
function plotX(sim, tol, t_end, exclude)
    clf()
    xs = molefractions(sim)
    maxes = maximum(xs, dims=2)

    # Filter time data up to t_end
    time_indices = findall(t -> t <= t_end, sim.sol.t)
    time_filtered = sim.sol.t[time_indices]
    xs_filtered = xs[:, time_indices]

    for i = 1:length(maxes)
        species_name = sim.domain.phase.species[i].name
        if maxes[i] > tol && !(species_name in exclude)
            plot(time_filtered, xs_filtered[i,:], label=species_name)
        end
    end
    legend()
    xlabel("Time (s)")
    ylabel("Concentration (mol/m^3)")
end
# Out:
# plotX (generic function with 1 method)

# %%
function plotC(sim, tol, t_end, exclude)
    clf()
    xs = concentrations(sim)
    maxes = maximum(xs, dims=2)

    # Filter time data up to t_end
    time_indices = findall(t -> t <= t_end, sim.sol.t)
    time_filtered = sim.sol.t[time_indices]
    xs_filtered = xs[:, time_indices]

    # Custom species order and their corresponding names and color
    species_order = ["CO2", "proton", "H2", "O=CO", "C=O", "CO-2", "CCO", "CH4", "OCO", "COC", "COCO", "CC(=O)O", "COC=O"]
    color_map = Dict("CO2" => "black", "proton" => "grey", "H2" => "green",
                        "O=CO" => "red", "C=O" => "brown", "CO-2" => "blue", "CCO" => "magenta",
                        "CH4" => "brown", "OCO" => "orange", "COC" => "teal", "COCO" => "lime", "CC(=O)O" => "teal", "COC=O" => "lime")
    # Replacement map for species labels
    replacement_map = Dict("CO-2" => "CH3OH", "O=CO" => "HCOOH", "C=O" => "HCHO",
                            "CCO" => "C2H5OH", "OCO" => "CH2(OH)2", "COC" => "CH3OCH3", "COCO" => "CH3OCH2OH", "CC(=O)O" => "CH3COOH", "COC=O" => "CH3OCHO")

    # Build a map of species names to indices
    name_to_index = Dict(sim.domain.phase.species[i].name => i for i in 1:length(sim.domain.phase.species))
    # Keep track of whether the species is plotted, used for later checks
    plotted = falses(length(sim.domain.phase.species))

    # Plot species from the custom species dictionary
    for species_name in species_order
        if species_name in exclude
            continue
        end

        if haskey(name_to_index, species_name)
            i = name_to_index[species_name]

            if (maxes[i] > tol) || (species_name == "proton") || (species_name == "CCO")  # Always plot proton and ethanol
                plot_label = get(replacement_map, species_name, species_name)
                plot_color = color_map[species_name]

                plot(time_filtered, xs_filtered[i, :]/1000, label=plot_label, color=plot_color)
                plotted[i] = true  # Mark as plotted
            end
        end
    end

    # Plot any remaining species that passed tolerance but were not in species_order
    for i in 1:length(sim.domain.phase.species)
        if plotted[i] || sim.domain.phase.species[i].name in exclude
            continue
        end

        if maxes[i] > tol
            species_name = sim.domain.phase.species[i].name
            plot(time_filtered, xs_filtered[i, :]/1000, label=species_name)  # Default color
        end
    end

    xlabel("Time (s)", fontsize=14)
    ylabel("Boundary Layer Concentration (mol/L)", fontsize=14)
    xticks(fontsize=14)
    yticks(fontsize=14)
    legend(loc="upper left", bbox_to_anchor=(0, 0.9), fontsize=12, ncol=2)
end
# Out:
# plotC (generic function with 1 method)

# %%
exclude_species = ["H2O"]
plotX(ssys.sims[1], 1e-12, 1e3, exclude_species)
xscale("log")
yscale("log")
xlim(1e-8, 1e3)
ylim(1e-16, 5)
title("Liquid-phase Mole Fractions vs. Time on Ag111@-1.0V")
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
exclude_species = ["H2O", "O=CC=O", "O=CCO", "CC=O"]
plotC(ssys.sims[1], 1e-10, 1e3, exclude_species)
xscale("log")
yscale("log")
xlim(1e-9, 1e3)
ylim(1e-20, 1e-1)
title("Ag111@-1.0V vs. R.H.E., d = 1 mm")
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
exclude_species = ["H2O"]
plotX(ssys.sims[2], 1e-3, 1e3, exclude_species)
xscale("log")
yscale("log")
xlim(1e-12, 1e3)
ylim(1e-6, 5)
title("Surface Mole Fractions vs. Time on Ag111@-1.0V")
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
#fd1 = getfluxdiagram(ssys,1;speciesratetolerance=1e-4)

# %%
#ts = 10.0 .^ range(-10, 3; step=1)
#fd1 = makefluxdiagrams(ssys, ts)

# %%
species_list = ["CO2", "CO2X", "CO2HX", "CH2O2X", "O=CO"];
spc_names = [s.name for s in ssys.species];
G_val = Float64[];
T = 300.0;

for spc in species_list
    ind = findfirst(==(spc), spc_names);
    if isnothing(ind)
        @warn "Species $spc not found"
        push!(G_val, NaN);
    else
        sp = ssys.species[ind];
        G = getGibbs(sp.thermo, T);
        push!(G_val, G);
    end
end

# %%
dG = G_val .- G_val[1];

clf()
for (i, name) in enumerate(species_list)
    if !isnan(dG[i])  # Skip NaN values
        hlines([dG[i]], xmin=i-0.4, xmax=i+0.4, label=name, linewidth=2)
    end
end
xlim(0, length(species_list)+1)
xlabel("Species")
ylabel("Relative Gibbs Energy (J/mol)")
legend()
grid(true, alpha=0.3)
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
function plotROP(ssys,name,t;N=0,tol=0.01)
    clf()
    rop = rops(ssys, name, t)
    inds = rop.nzind[reverse(sortperm(abs.(rop.nzval)))]
    if N == 0
        N = length(inds)
    elseif N > length(inds)
        N = length(inds)
    end
    inds = inds[1:N]
    mval = abs(rop[inds[1]])
    minval = mval*tol
    k = 1
    while k < length(inds) && abs(rop[inds[k]]) >= minval
        k += 1
    end
    inds = inds[1:k]
    net_rops = sum(rop[inds])
    println("Net ROPs for species $name is: $net_rops")

    for (i, j) in enumerate(inds)
        println("Showing the reaction with $i th highest ROP for species $name:")
        println(getrxnstr(ssys.reactions[j]))
        println("ROP = ", rop[inds[i]])
        println(ssys.reactions[j].kinetics)
    end

    xs = Array{Float64,1}(1:length(inds))
    barh(xs,reverse(rop[inds]))
    yticks(xs,reverse(getrxnstr.(ssys.reactions[inds])))
    xlabel("Production/Loss Rate mol/s")
    gcf()
end
# Out:
# plotROP (generic function with 1 method)

# %%
function PrintKinDetail(inter, speciesname)
    println("Showing Kinetics details for reactions involving species $speciesname\n")
    for (i,rxn) in enumerate(inter.reactions)
        flag = false
        for j = 1:length(rxn.reactants)
            if rxn.reactants[j].name == speciesname
                flag = true
            end
        end
        for j = 1:length(rxn.products)
            if rxn.products[j].name == speciesname
                flag = true
            end
        end
        if flag
            println(getrxnstr(rxn))
            println(rxn.kinetics)
            kf = inter.kfs[i]
            krev = inter.krevs[i]
            kc = kf/krev
            println("kf = $kf")
            println("krev = $krev")
            println("Kc = $kc\n")
        end
    end
end
# Out:
# PrintKinDetail (generic function with 1 method)

# %%
"""
Integrates the ROP in the boundary layer and computes the concentration
"""
function get_boundary_layer_concentration(sim,t,spc,Vbl,C_0)
    intg,err = quadgk(x -> sum(rops(sim,spc,t)), 0, t);
    return C_0 + intg ./ Vbl;
end
# Out:
# get_boundary_layer_concentration

# %%
"""
diffusive flux to the reservoir using concentration from ROP integration
"""
function flux_to_reservoir_2(bsol,t,spc,Vbl,C_0,reservoirinterface)
    cs = get_boundary_layer_concentration(bsol,t,spc,Vbl,C_0)
    spc_idx = findfirst(s -> s.name == spc, bsol.sims[1].species)
    d = bsol.sims[1].domain.diffusivity[spc_idx];
    c_res = reservoirinterface.c[spc_idx];
    return reservoirinterface.A * d * (cs - c_res) / reservoirinterface.layer_thickness
end
# Out:
# flux_to_reservoir_2

# %%
# Compute ROP over time
ROP_vals = [sum(rops(ssys, "O=CO", t)) for t in t_vals];
# Compute boundary layer accumulation by integration
Cbl_vals = [get_boundary_layer_concentration(ssys, t, "O=CO", V_bl, C_default) for t in t_vals];
# Compute flux over time using Cbl_vals
F_vals = [flux_to_reservoir_2(ssys, t, "O=CO", V_bl, C_default, diffusionlayer) for t in t_vals];

# %%
# Plots the ROP of O=CO
clf()

plot(t_vals, ROP_vals)

xscale("log")
xlim(1e-11,1e3)
yscale("log")
ylim(1e-8,1e2)
xlabel("Time (s)")
ylabel("Rate of Progress (mol/s)")
legend()
tight_layout()
gcf()
# Out:
# sys:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
# Plots the Boundary Layer Concentration of O=CO from ROP Integration WITHOUT Diffusion Flux Into Reservoir
clf()

plot(t_vals, Cbl_vals)

xscale("log")
xlim(1e-11,1e3)
yscale("log")
ylim(1e-13,1e1)
xlabel("Time (s)")
ylabel("Concentration (mol/m^3)")
title("Boundary Layer Accumulation of O=CO from ROP Integration")
legend()
tight_layout()
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
# Plots the Diffusive Flux of O=CO using ROP Integration
clf()

plot(t_vals, F_vals)

xscale("log")
xlim(1e-11,1e3)
yscale("log")
ylim(1e-15,1e1)
xlabel("Time (s)")
ylabel("Diffusive Flux (mol/m^3)")
title("Diffusive Flux of O=CO from ROP Integration")
legend()
tight_layout()
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
# Plots the Diffusion Flux Into Reservoir Using Integrated Concentration from ROP Analysis
clf()

plot(t_vals, F_vals)

xscale("log")
yscale("log")
xlabel("Time (s)")
ylabel("Diffusive Flux")
title("Diffusive Flux of O=CO from ROP Integration")
legend()
tight_layout()
gcf()
# Out:
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys, "proton",1;N=15,tol=0.0)
# Out:
# Net ROPs for species proton is: -0.033551999422431436
# Showing the reaction with 1 th highest ROP for species proton:
# proton+CO2X<=>CO2HX
# ROP = -0.03266243210152375
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 72363.75
#   q: Float64 0.62
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species proton:
# proton+CO2HX<=>H2O+OCX
# ROP = -0.0006960485199832404
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 24121.25
#   q: Float64 0.36
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species proton:
# proton+vacantX<=>HX
# ROP = -8.68957040697782e-5
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 1.0e13
#   n: Float64 1.0
#   Ea: Float64 40571.9425
#   q: Float64 0.5
#   V0: Float64 -0.559
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species proton:
# HX+proton<=>H2+vacantX
# ROP = -8.656838037436486e-5
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 1.0e13
#   n: Float64 1.0
#   Ea: Float64 94507.0575
#   q: Float64 0.5
#   V0: Float64 0.559
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species proton:
# proton+OCX<=>CHOX
# ROP = -2.0022315009167425e-5
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 43418.25
#   q: Float64 0.49
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species proton:
# proton+CO2X<=>CHO2X
# ROP = -2.39274031221371e-8
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e14
#   n: Float64 0.0
#   Ea: Float64 120606.25
#   q: Float64 0.46
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species proton:
# proton+OCX<=>OC#[Pt]
# ROP = -7.562938277205491e-9
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 59907.674739328526
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species proton:
# proton+HX<=>[H][H].[Pt]
# ROP = -7.258794262482378e-10
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.4999999999999992e10
#   n: Float64 0.0
#   Ea: Float64 26879.12942447813
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species proton:
# proton+CH2OX<=>CO[Pt]
# ROP = -1.5846565622404525e-10
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.4999999999999992e10
#   n: Float64 0.0
#   Ea: Float64 63847.33033518879
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species proton:
# proton+CH2OX<=>OC[Pt]
# ROP = -2.489667939309621e-11
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 72802.9367584667
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 11 th highest ROP for species proton:
# proton+CH2O2X<=>OC(O)[Pt]
# ROP = -1.8873485630042688e-12
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 115347.50806876807
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 12 th highest ROP for species proton:
# proton+CH2O2X<=>OCO[Pt]
# ROP = -5.952977148325643e-16
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.4999999999999992e10
#   n: Float64 0.0
#   Ea: Float64 135330.8126653866
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 13 th highest ROP for species proton:
# proton+OC#[Pt]<=>OC=[Pt]
# ROP = -9.111239259986373e-18
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 6494.139830952408
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 14 th highest ROP for species proton:
# proton+OC[Pt]<=>CO.[Pt]
# ROP = -7.078849723271115e-18
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 42806.97689092044
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 15 th highest ROP for species proton:
# proton+OC=[Pt]<=>OC[Pt]
# ROP = -5.9501134299403755e-18
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 18016.620825042337
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys, "HX",sol.t[end];N=15,tol=0.0)
# Out:
# Net ROPs for species HX is: -1.044661082489604e-8
# Showing the reaction with 1 th highest ROP for species HX:
# proton+vacantX<=>HX
# ROP = 0.0004502275123656474
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 1.0e13
#   n: Float64 1.0
#   Ea: Float64 40571.9425
#   q: Float64 0.5
#   V0: Float64 -0.559
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species HX:
# HX+CHOX<=>vacantX+CH2OX
# ROP = -0.0003013157311467781
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.932e17
#   n: Float64 0.0
#   Ea: Float64 45348.110910469884
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species HX:
# HX+proton<=>H2+vacantX
# ROP = -0.00014821512811216572
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 1.0e13
#   n: Float64 1.0
#   Ea: Float64 94507.0575
#   q: Float64 0.5
#   V0: Float64 0.559
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species HX:
# vacantX+OC=[Pt]<=>HX+OC#[Pt]
# ROP = -4.3603055952620067e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 3.71e17
#   n: Float64 0.0
#   Ea: Float64 93756.32377828495
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species HX:
# vacantX+vacantX+H2<=>HX+HX
# ROP = -2.608177393100596e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.2433571337995386e9
#   n: Float64 0.5000000000052115
#   Ea: Float64 88008.54855901783
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species HX:
# HX+CO2HX<=>vacantX+CH2O2X
# ROP = -8.785395374165514e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.308e18
#   n: Float64 0.0
#   Ea: Float64 70434.29992477236
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species HX:
# proton+HX<=>[H][H].[Pt]
# ROP = -1.2427899388912096e-9
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.4999999999999992e10
#   n: Float64 0.0
#   Ea: Float64 26879.12942447813
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species HX:
# vacantX+OC[Pt]<=>HX+OC=[Pt]
# ROP = -2.0785268532697615e-10
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 7.42e17
#   n: Float64 0.0
#   Ea: Float64 147645.00519853202
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species HX:
# H2OX+OCX<=>HX+CO2HX
# ROP = -7.499205379201248e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 5.909597697728364e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species HX:
# vacantX+O=C([Pt])C[Pt]<=>HX+O=C([Pt])C=[Pt]
# ROP = -7.295938317838915e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.7500000000000006e17
#   n: Float64 0.0
#   Ea: Float64 139365.54324817867
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 11 th highest ROP for species HX:
# [H][H].[Pt]+OCX<=>HX+CHOX
# ROP = -1.3706583306936368e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 5.909597697728364e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 12 th highest ROP for species HX:
# HX+CO2<=>CO2HX
# ROP = 9.825373609244316e-13
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 23923.775173657334
#   n: Float64 0.5
#   Ea: Float64 73060.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 13 th highest ROP for species HX:
# vacantX+COC=O.[Pt]<=>HX+COC(=O)[Pt]
# ROP = -1.299186960456149e-13
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 3.4534874337147363e13
#   n: Float64 0.8828711760583632
#   Ea: Float64 120004.17587369937
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 14 th highest ROP for species HX:
# HX+OCX<=>vacantX+CHOX
# ROP = -5.011368337663763e-14
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 3.14e17
#   n: Float64 0.0
#   Ea: Float64 95520.48893907486
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 15 th highest ROP for species HX:
# vacantX+CH2X<=>HX+CHX
# ROP = -1.739680683332318e-14
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 7.31e18
#   n: Float64 0.0
#   Ea: Float64 95249.78380839253
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys, "OCX",sol.t[end];N=15,tol=0.0)
# Out:
# Net ROPs for species OCX is: -5.369440234291236e-8
# Showing the reaction with 1 th highest ROP for species OCX:
# proton+CO2HX<=>H2O+OCX
# ROP = 0.0012668369111846645
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 24121.25
#   q: Float64 0.36
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species OCX:
# proton+OCX<=>CHOX
# ROP = -0.0012396005483166672
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 43418.25
#   q: Float64 0.49
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species OCX:
# vacantX+COC(=O)[Pt]<=>OCX+CO[Pt]
# ROP = -2.7438402790819518e-5
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.46e20
#   n: Float64 -0.213
#   Ea: Float64 108408.38075667131
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species OCX:
# proton+OCX<=>OC#[Pt]
# ROP = -4.360305481814008e-7
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 59907.674739328526
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species OCX:
# CO2HX+OC=[Pt]<=>OCX+OC(O)[Pt]
# ROP = 4.3581537557908884e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.39e17
#   n: Float64 0.101
#   Ea: Float64 19000.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species OCX:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species OCX:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species OCX:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species OCX:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species OCX:
# OCX+CO[Pt]<=>OX+CC(=O)[Pt]
# ROP = -7.657880202418895e-10
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.39e17
#   n: Float64 0.101
#   Ea: Float64 19000.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 11 th highest ROP for species OCX:
# OX+CHOX<=>HOX+OCX
# ROP = 7.654286371172827e-10
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 3.298e17
#   n: Float64 0.0
#   Ea: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 12 th highest ROP for species OCX:
# OCX+CH2OX<=>CHOX+CHOX
# ROP = 4.5906861516641013e-11
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 5.909597697728364e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 13 th highest ROP for species OCX:
# H2OX+OCX<=>HX+CO2HX
# ROP = 7.499205379201248e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 5.909597697728364e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 14 th highest ROP for species OCX:
# proton+O=C([Pt])C[Pt]<=>OCX+CH3X
# ROP = 7.317435637683772e-12
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 39888.61730671122
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 15 th highest ROP for species OCX:
# CHX+CO2HX<=>OCX+OC=[Pt]
# ROP = -7.313912162120112e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.4e18
#   n: Float64 0.101
#   Ea: Float64 42400.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys, "O=CO",sol.t[end];N=15,tol=0.0)
# Out:
# Net ROPs for species O=CO is: 0.014422545903101052
# Showing the reaction with 1 th highest ROP for species O=CO:
# vacantX+O=CO<=>CH2O2X
# ROP = 0.014422545903093067
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 23393.95035932193
#   n: Float64 0.4999999999997328
#   Ea: Float64 1.6648943897904221e-9
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species O=CO:
# vacantX+vacantX+O=CO<=>HOX+CHOX
# ROP = 6.67864542677311e-15
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 7.655088468348621e7
#   n: Float64 0.49999999999999967
#   Ea: Float64 132375.38628664665
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species O=CO:
# HX+O=CO<=>OC(O)[Pt]
# ROP = 1.1423114009078666e-15
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 11696.975179639288
#   n: Float64 0.49999999999997113
#   Ea: Float64 73060.00000000017
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species O=CO:
# vacantX+vacantX+O=CO<=>HX+CO2HX
# ROP = 1.642849902783622e-16
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.0206784624464774e9
#   n: Float64 0.5000000000000004
#   Ea: Float64 136711.0572887129
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species O=CO:
# HX+O=CO<=>OCO[Pt]
# ROP = -1.8662535381603327e-19
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 11696.975179639288
#   n: Float64 0.49999999999997113
#   Ea: Float64 73060.00000000017
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species O=CO:
# vacantX+vacantX+O=CO<=>HX+CHO2X
# ROP = 3.646991833864053e-25
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.0206784624464848e9
#   n: Float64 0.49999999999999944
#   Ea: Float64 176038.66814912477
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species O=CO:
# vacantX+vacantX+O=CO<=>OX+OC=[Pt]
# ROP = 5.342212852380617e-26
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.0206784624465084e8
#   n: Float64 0.4999999999999965
#   Ea: Float64 257417.6656875024
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species O=CO:
# proton+O=COC[Pt]<=>CH2X+O=CO
# ROP = 1.4261109157511902e-30
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 64651.660819360055
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species O=CO:
# proton+O=C(O)C=[Pt]<=>CHX+O=CO
# ROP = -1.9516458174003528e-36
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 45734.37564534281
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species O=CO:
# proton+O=C(O)C[Pt]<=>CH2X+O=CO
# ROP = -1.0684640668447576e-39
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 130830.26178561061
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 11 th highest ROP for species O=CO:
# proton+O=COC=[Pt]<=>CHX+O=CO
# ROP = 4.370307457157099e-51
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 51447.34412179033
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 12 th highest ROP for species O=CO:
# proton+O=C(O)C#[Pt]<=>CX+O=CO
# ROP = -6.082096990667336e-53
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 130354.10328483029
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 13 th highest ROP for species O=CO:
# proton+O=COC#[Pt]<=>CX+O=CO
# ROP = 2.00245447174561e-68
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 38998.96922048947
#   q: Float64 0.25
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys,"CH2O2X",sol.t[end];N=15,tol=0.0)
# Out:
# Net ROPs for species CH2O2X is: -4.1891921493202435e-6
# Showing the reaction with 1 th highest ROP for species CH2O2X:
# vacantX+O=CO<=>CH2O2X
# ROP = -0.014422545903093067
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 23393.95035932193
#   n: Float64 0.4999999999997328
#   Ea: Float64 1.6648943897904221e-9
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species CH2O2X:
# CO2HX+CO2HX<=>CO2X+CH2O2X
# ROP = 0.014417313298679478
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 64984.89719971026
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species CH2O2X:
# CO2HX+OC(O)[Pt]<=>CH2O2X+CH2O2X
# ROP = 8.548561747166947e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 8.36e17
#   n: Float64 0.0
#   Ea: Float64 10760.85577299056
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species CH2O2X:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species CH2O2X:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species CH2O2X:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species CH2O2X:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = 3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species CH2O2X:
# HX+CO2HX<=>vacantX+CH2O2X
# ROP = 8.785395374165514e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.308e18
#   n: Float64 0.0
#   Ea: Float64 70434.29992477236
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species CH2O2X:
# CHOX+OC(O)[Pt]<=>CH2OX+CH2O2X
# ROP = 8.433740693112722e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 8.36e17
#   n: Float64 0.0
#   Ea: Float64 27698.892750596395
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species CH2O2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = 5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 11 th highest ROP for species CH2O2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = 5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 12 th highest ROP for species CH2O2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = 5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 13 th highest ROP for species CH2O2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = 5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 14 th highest ROP for species CH2O2X:
# vacantX+CH2O2X<=>HOX+CHOX
# ROP = 6.008738995010598e-10
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.781e17
#   n: Float64 0.0
#   Ea: Float64 174098.9801398976
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 15 th highest ROP for species CH2O2X:
# CO2HX+CC(=O)[Pt]<=>CH2O2X+C=C=O.[Pt]
# ROP = 5.7087355015953404e-11
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.254e18
#   n: Float64 0.0
#   Ea: Float64 90442.90838773352
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys,"CHO2X",sol.t[end];N=10,tol=0.0)
# Out:
# Net ROPs for species CHO2X is: -5.84995281444867e-15
# Showing the reaction with 1 th highest ROP for species CHO2X:
# proton+CO2X<=>CHO2X
# ROP = 2.2280617226300608e-8
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e14
#   n: Float64 0.0
#   Ea: Float64 120606.25
#   q: Float64 0.46
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species CHO2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = -5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species CHO2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = -5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species CHO2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = -5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species CHO2X:
# CHO2X+CO2HX<=>CO2X+CH2O2X
# ROP = -5.542837339090672e-9
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 26227.25171408696
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species CHO2X:
# CHOX+CHO2X<=>CO2X+CH2OX
# ROP = -1.0936776058996586e-10
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 43165.28869169279
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species CHO2X:
# CHO2X<=>CO2HX
# ROP = 5.342231532207226e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.4999999999999995e12
#   n: Float64 0.0
#   Ea: Float64 60523.33333333338
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species CHO2X:
# CHOX+CHO2X<=>OCX+CH2O2X
# ROP = -5.323538888716214e-12
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 7.475e18
#   n: Float64 0.0
#   Ea: Float64 57891.205417621124
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species CHO2X:
# CHO2X+CH2OX<=>CHOX+CH2O2X
# ROP = 8.21853516201436e-14
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 8.36e17
#   n: Float64 0.0
#   Ea: Float64 52308.909536124585
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species CHO2X:
# HX+CO2<=>CHO2X
# ROP = -6.837295880873708e-15
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 23923.775173657334
#   n: Float64 0.5
#   Ea: Float64 73060.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys,"CO2HX",sol.t[end];N=10,tol=0.0)
# Out:
# Net ROPs for species CO2HX is: 7.588869563715608e-8
# Showing the reaction with 1 th highest ROP for species CO2HX:
# proton+CO2X<=>CO2HX
# ROP = 0.03041446420828748
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 72363.75
#   q: Float64 0.62
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species CO2HX:
# CO2HX+CO2HX<=>CO2X+CH2O2X
# ROP = -0.028834626597358956
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 64984.89719971026
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species CO2HX:
# proton+CO2HX<=>H2O+OCX
# ROP = -0.0012668369111846645
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 24121.25
#   q: Float64 0.36
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species CO2HX:
# CHOX+CO2HX<=>CO2X+CH2OX
# ROP = -0.00028447330777999006
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 81922.93417731601
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 5 th highest ROP for species CO2HX:
# CO2HX+COC(=O)[Pt]<=>CO2X+CC(=O)O.[Pt]
# ROP = -2.7438398221297948e-5
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 3547.92376708347
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 6 th highest ROP for species CO2HX:
# CO2HX+OC=[Pt]<=>OCX+OC(O)[Pt]
# ROP = -4.3581537557908884e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.39e17
#   n: Float64 0.101
#   Ea: Float64 19000.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 7 th highest ROP for species CO2HX:
# CO2HX+OC(O)[Pt]<=>CH2O2X+CH2O2X
# ROP = -4.2742808735834735e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 8.36e17
#   n: Float64 0.0
#   Ea: Float64 10760.85577299056
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 8 th highest ROP for species CO2HX:
# CO2HX+CO[Pt]<=>CO2X+CO.[Pt]
# ROP = -7.560776255932846e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 4.18e17
#   n: Float64 0.0
#   Ea: Float64 8909.091876453938
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 9 th highest ROP for species CO2HX:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = -3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 10 th highest ROP for species CO2HX:
# OCX+CH2O2X<=>CHOX+CO2HX
# ROP = -3.712691071859374e-8
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.954798848864182e14
#   n: Float64 0.9956894270665808
#   Ea: Float64 123451.6909068545
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys,"OCX",sol.t[end])
# Out:
# Net ROPs for species OCX is: -6.38070471003623e-7
# Showing the reaction with 1 th highest ROP for species OCX:
# proton+CO2HX<=>H2O+OCX
# ROP = 0.0012668369111846645
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 24121.25
#   q: Float64 0.36
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species OCX:
# proton+OCX<=>CHOX
# ROP = -0.0012396005483166672
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 43418.25
#   q: Float64 0.49
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 3 th highest ROP for species OCX:
# vacantX+COC(=O)[Pt]<=>OCX+CO[Pt]
# ROP = -2.7438402790819518e-5
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 1.46e20
#   n: Float64 -0.213
#   Ea: Float64 108408.38075667131
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 4 th highest ROP for species OCX:
# proton+OCX<=>OC#[Pt]
# ROP = -4.360305481814008e-7
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 2.5e10
#   n: Float64 0.0
#   Ea: Float64 59907.674739328526
#   q: Float64 0.5
#   V0: Float64 0.0
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)

# %%
plotROP(ssys,"H2",sol.t[end])
# Out:
# Net ROPs for species H2 is: 0.00014834553698182075
# Showing the reaction with 1 th highest ROP for species H2:
# HX+proton<=>H2+vacantX
# ROP = 0.00014821512811216572
# Arrheniusq{Float64, Float64, Float64, Float64, EmptyRateUncertainty, Float64}
#   A: Float64 1.0e13
#   n: Float64 1.0
#   Ea: Float64 94507.0575
#   q: Float64 0.5
#   V0: Float64 0.559
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
#
# Showing the reaction with 2 th highest ROP for species H2:
# vacantX+vacantX+H2<=>HX+HX
# ROP = 1.304088696550298e-7
# Arrhenius{Float64, Float64, Float64, EmptyRateUncertainty}
#   A: Float64 2.2433571337995386e9
#   n: Float64 0.5000000000052115
#   Ea: Float64 88008.54855901783
#   unc: EmptyRateUncertainty EmptyRateUncertainty()
# Figure(<py Figure size 640x480 with 1 Axes>)
# Figure(<py Figure size 640x480 with 1 Axes>)
